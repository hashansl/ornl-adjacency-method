# %% [markdown]
# Add geographical information to overdose data

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gdp

# %%
overdose_path = "/home/h6x/git_projects/ornl-svi-data-processing/raw_data/HepVu_County_Opioid_Indicators_05DEC22.xlsx"

# %%
overdose_df = pd.read_excel(overdose_path)

# %%
overdose_df.columns
# Out:
# Index(['GEO ID', 'State Abbreviation', 'County Name',
#        'Opioid Prescription Rate 2020',
#        'Narcotic Overdose Mortality Rate 2014',
#        'Narcotic Overdose Mortality Rate 2015',
#        'Narcotic Overdose Mortality Rate 2016',
#        'Narcotic Overdose Mortality Rate 2017',
#        'Narcotic Overdose Mortality Rate 2018',
#        'Narcotic Overdose Mortality Rate 2019',
#        'Narcotic Overdose Mortality Rate 2020'],
#       dtype='object')

# %%
overdose_df.head()
# Out:
#    GEO ID State Abbreviation     County Name  Opioid Prescription Rate 2020  \
# 0    1001                 AL  Autauga County                           98.3
# 1    1003                 AL  Baldwin County                           65.0
# 2    1005                 AL  Barbour County                           22.8
# 3    1007                 AL     Bibb County                           24.8
# 4    1009                 AL   Blount County                           22.8
#
#    Narcotic Overdose Mortality Rate 2014  \
# 0                                    8.2
# 1                                   18.0
# 2                                    4.4
# 3                                   17.2
# 4                                   18.6
#
#    Narcotic Overdose Mortality Rate 2015  \
# 0                                    8.8
# 1                                   20.0
# 2                                    4.5
# 3                                   16.6
# 4                                   18.9
#
#    Narcotic Overdose Mortality Rate 2016  \
# 0                                   10.7
# 1                                   16.6
# 2                                    5.7
# 3                                   22.6
# 4                                   22.7
#
#    Narcotic Overdose Mortality Rate 2017  \
# 0                                    9.8
# 1                                   15.1
# 2                                    5.8
# 3                                   21.7
# 4                                   27.0
#
#    Narcotic Overdose Mortality Rate 2018  \
# 0                                   10.9
# 1                                   14.9
# 2                                    5.2
# 3                                   23.1
# 4                                   19.9
#
#    Narcotic Overdose Mortality Rate 2019  \
# 0                                    9.2
# 1                                   14.5
# 2                                    5.7
# 3                                   19.4
# 4                                   20.3
#
#    Narcotic Overdose Mortality Rate 2020
# 0                                   11.6
# 1                                   27.4
# 2                                    7.6
# 3                                   27.3
# 4                                   24.2

# %%
# renama column 'Opioid Prescription Rate 2020' to pres_r_2020
overdose_df.rename(columns={'Opioid Prescription Rate 2020':'pres_r_2020'}, inplace=True)


overdose_df.rename(columns={'Narcotic Overdose Mortality Rate 2014':'NOD_2014'}, inplace=True)
overdose_df.rename(columns={'Narcotic Overdose Mortality Rate 2015':'NOD_2015'}, inplace=True)
overdose_df.rename(columns={'Narcotic Overdose Mortality Rate 2016':'NOD_2016'}, inplace=True)
overdose_df.rename(columns={'Narcotic Overdose Mortality Rate 2017':'NOD_2017'}, inplace=True)
overdose_df.rename(columns={'Narcotic Overdose Mortality Rate 2018':'NOD_2018'}, inplace=True)
overdose_df.rename(columns={'Narcotic Overdose Mortality Rate 2019':'NOD_2019'}, inplace=True)
overdose_df.rename(columns={'Narcotic Overdose Mortality Rate 2020':'NOD_2020'}, inplace=True)

# %%
def preprocess_overdose_data(overdose_df):
    """Preprocess overdose data."""
    overdose_df['GEO ID'] = overdose_df['GEO ID'].astype(str)
    overdose_df['GEO ID'] = overdose_df['GEO ID'].apply(lambda x: x.zfill(5))
    return overdose_df

# %%
overdose_df = preprocess_overdose_data(overdose_df)

# %%
svi_df = gdp.read_file("/home/h6x/git_projects/ornl-svi-data-processing/raw_data/svi/2018/SVI2018_US_county.gdb")

# %%
overdose_df_ = svi_df.merge(overdose_df, how='left', left_on='FIPS', right_on='GEO ID')

# %%
overdose_df_
# Out:
#       ST       STATE ST_ABBR      COUNTY   FIPS  \
# 0     35  NEW MEXICO      NM  Rio Arriba  35039
# 1     01     ALABAMA      AL     Autauga  01001
# 2     01     ALABAMA      AL      Blount  01009
# 3     01     ALABAMA      AL      Butler  01013
# 4     01     ALABAMA      AL     Calhoun  01015
# ...   ..         ...     ...         ...    ...
# 3137  48       TEXAS      TX       Duval  48131
# 3138  48       TEXAS      TX      Zapata  48505
# 3139  48       TEXAS      TX      Zavala  48507
# 3140  48       TEXAS      TX      Dimmit  48127
# 3141  48       TEXAS      TX    Jim Hogg  48247
#
#                            LOCATION    AREA_SQMI  E_TOTPOP  M_TOTPOP   E_HU  \
# 0     Rio Arriba County, New Mexico  5860.869195     39307         0  20044
# 1           Autauga County, Alabama   594.443459     55200         0  23315
# 2            Blount County, Alabama   644.830460     57645         0  24222
# 3            Butler County, Alabama   776.838201     20025         0  10026
# 4           Calhoun County, Alabama   605.867251    115098         0  53682
# ...                             ...          ...       ...       ...    ...
# 3137            Duval County, Texas  1793.476183     11355         0   5592
# 3138           Zapata County, Texas   998.411980     14369         0   6388
# 3139           Zavala County, Texas  1297.406535     12131         0   4344
# 3140           Dimmit County, Texas  1328.884075     10663         0   4408
# 3141         Jim Hogg County, Texas  1136.172598      5282         0   2523
#
#       ...  State Abbreviation      County Name  pres_r_2020  NOD_2014  \
# 0     ...                  NM  Rio Arriba Coun         33.4      87.9
# 1     ...                  AL   Autauga County         98.3       8.2
# 2     ...                  AL    Blount County         22.8      18.6
# 3     ...                  AL    Butler County         35.1       7.4
# 4     ...                  AL   Calhoun County         97.9      14.8
# ...   ...                 ...              ...          ...       ...
# 3137  ...                  TX     Duval County          3.1       9.3
# 3138  ...                  TX    Zapata County          3.8       6.5
# 3139  ...                  TX    Zavala County          2.6       6.1
# 3140  ...                  TX    Dimmit County          6.0       8.4
# 3141  ...                  TX  Jim Hogg County         -9.0       6.2
#
#       NOD_2015  NOD_2016  NOD_2017  NOD_2018  NOD_2019  NOD_2020
# 0         70.4      79.0      79.3      80.0      70.8     101.3
# 1          8.8      10.7       9.8      10.9       9.2      11.6
# 2         18.9      22.7      27.0      19.9      20.3      24.2
# 3          8.6      10.8       9.8       8.8      10.2      14.3
# 4         16.0      14.6      23.4      15.8      17.5      24.5
# ...        ...       ...       ...       ...       ...       ...
# 3137       9.5      12.2      11.6      12.5      12.9      16.3
# 3138       7.0       9.5       9.1       8.2       8.9      11.3
# 3139       7.0       8.0       8.1       8.2       8.4      10.8
# 3140       6.7       8.1       8.2       8.9       8.0      11.0
# 3141       6.3       7.7       7.8       7.4       7.6      10.5
#
# [3142 rows x 137 columns]

# %%
overdose_df_.shape
# Out:
# (3142, 137)

# %%
# save overdose_df_ to a geopandas file

overdose_df_.to_file("/home/h6x/git_projects/ornl-adjacency-method/overdose_graphs/processed_data/overdose_with_svi/overdose_df.shp")
# Out:
# /tmp/ipykernel_3154582/774063764.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   overdose_df_.to_file("/home/h6x/git_projects/ornl-adjacency-method/overdose_graphs/processed_data/overdose_with_svi/overdose_df.shp")
